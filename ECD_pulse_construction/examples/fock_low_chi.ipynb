# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from ECD_control.ECD_pulse_construction.ECD_pulse_construction import *
from ECD_control.ECD_tools.ECD_tools import *
import qutip as qt

# %%
#the parameters in our circuit. Can be user defined, or loaded from the result of an ECD optimization.
fname = 'fock_2.npz'
betas = np.load(fname)['betas']
phis = np.load(fname)['phis']
thetas = np.load(fname)['thetas']

#betas = np.array([2*np.sqrt(2.0), -2*np.sqrt(2.0),0.0])
#phis = np.array([0.0, 0.0,0.0])
#thetas = np.array([0.0,0.0])
#thetas = np.array([np.pi/2.0,0.0,np.pi/2.0])
#betas = np.array([2*np.sqrt(2.0),0])
#phis = np.array([0.0,0])
#thetas = np.array([np.pi/2.0,np.pi/2.0])
print('betas:' + str(betas))
print('phis:' + str(phis))
print('thetas:' + str(thetas))
# Out:
# betas:[ 1.4546283 +2.1571472j   0.7158418 +0.43076843j  1.948099  -1.2958955j
#   0.08880814-0.5655835j  -0.29272085-0.9692059j  -0.00365159+0.00379038j]
# phis:[ 0.         1.6041893 -1.5836263  1.6055623  1.5414847 -3.1094034]
# thetas:[ 1.567499  -0.8095143 -1.0500791  1.0925623 -1.1011343 -1.5761303]

# %%
#Now, the unitary simulation
print('the circuit:')
print('betas: ' + str(betas))
print('phis deg: ' + str(180*phis/np.pi))
print('thetas deg: ' + str(180*thetas/np.pi))
N = 30
psi0 = qt.tensor(qt.basis(2,0),qt.basis(N,0))
fock = 2
psit = qt.tensor(qt.basis(2,1),qt.basis(N,fock))
#psis = unitary_circuit_sim(psi0, betas, phis, thetas, N)
psif = psis[-1]
plot_expect(psis)
g = qt.tensor(qt.basis(2,0), qt.identity(N))
e = qt.tensor(qt.basis(2,1), qt.identity(N))
psi_g = (g.dag()*psif).unit()
psi_e = (e.dag()*psif).unit()
xvec = np.linspace(-3,3,81)
plot_wigner(psi_g, xvec)
plot_wigner(psi_e, xvec, invert=False)
plt.title('unitary sim')
# Out:
# the circuit:
# betas: [ 1.4546283 +2.1571472j   0.7158418 +0.43076843j  1.948099  -1.2958955j
#   0.08880814-0.5655835j  -0.29272085-0.9692059j  -0.00365159+0.00379038j]
# phis deg: [   0.         91.91327   -90.7351     91.99194    88.320564 -178.15569 ]
# thetas deg: [ 89.81108  -46.381752 -60.1651    62.59921  -63.090347 -90.30561 ]
# Text(0.5, 1.0, 'unitary sim')

# %%
#Our cavity and qubit. When using pulse construction on the FPGA, these objects can be loaded, and 
#the pre-calibrated values can be used. Here, we are making a "FakeCavity" and a "FakeQubit" in order
#to demonstrate the pulse construction when not connected to the FPGA_lib.

#The following parameters are assumed to be defined under your cavity and qubit entity object in FPGA lib.
storage_params = {'chi_kHz': -30, 'chi_prime_Hz': 0, 'Ks_Hz': 0, 'epsilon_m_MHz': 0, 'unit_amp': 0.01, 'sigma': 11, 'chop': 4}
qubit_params = {'unit_amp': 0.1, 'sigma': 4, 'chop': 2, 'detune':0}

#calculating epsilon m
wave = storage_params['unit_amp']*gaussian_wave(storage_params['sigma'], storage_params['chop'])
epsilon_m = 1/np.trapz(wave)
epsilon_m_MHz = 1e3*epsilon_m/2/np.pi
print('epsilon_m_MHz: %.6f' % epsilon_m_MHz)
storage_params['epsilon_m_MHz'] = epsilon_m_MHz

pi = rotate(np.pi, phi=0, sigma=qubit_params['sigma'], chop=qubit_params['chop'], dt=1)
Omega_m = np.real(np.max(pi))/qubit_params['unit_amp']

#creating the "Fake storage" and "Fake qubit"
storage = FakeStorage(**storage_params)
qubit = FakeQubit(**qubit_params)

#The alpha used during the ECD gates.
alpha_CD = 4
#Buffer time between R and ECD pulses.
buffer_time = 0
# Out:
# epsilon_m_MHz: 691.654892

# %%
#generating the conditional displacement circuit with all corrections.
cd_circuit_dict = conditional_displacement_circuit(betas, phis, thetas, storage, qubit,
                     alpha_CD,  buffer_time=buffer_time, kerr_correction = False, chi_prime_correction=False, final_disp=True, pad=True, output=True,
                     echo_qubit_pulses=False, qubit_phase_correction=True)
cavity_dac_pulse, qubit_dac_pulse, = cd_circuit_dict['cavity_dac_pulse'], cd_circuit_dict['qubit_dac_pulse']
print(cd_circuit_dict['alphas'])
# Out:
# 0
#   mid_disp: 0.0000 final_disp: 0.0000 first_radius: 4.0000 second_radius: 4.0001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-7bc8ffe574cd> in <module>
#       1 #generating the conditional displacement circuit with all corrections.
# ----> 2 cd_circuit_dict = conditional_displacement_circuit(betas, phis, thetas, storage, qubit,
#       3                      alpha_CD,  buffer_time=buffer_time, kerr_correction = False, chi_prime_correction=False, final_disp=True, pad=True, output=True,
#       4                      echo_qubit_pulses=False, qubit_phase_correction=True)
#       5 cavity_dac_pulse, qubit_dac_pulse, = cd_circuit_dict['cavity_dac_pulse'], cd_circuit_dict['qubit_dac_pulse']
#
# D:\alec\Projects\CD_universal_control\Simulations\ECD_control\ECD_pulse_construction\ECD_pulse_construction.py in conditional_displacement_circuit(betas, phis, thetas, storage, qubit, alpha_CD, final_disp, buffer_time, curvature_correction, qubit_phase_correction, chi_prime_correction, kerr_correction, pad, double_CD, finite_difference, output, echo_qubit_pulses)
#    1055                     beta != last_beta
#    1056                 ):  # don't construct the next one if it's the same beta...no need...
# -> 1057                     e_cd, o_cd, alpha, tw = conditional_displacement(
#    1058                         beta,
#    1059                         alpha=alpha_CD,
#
# D:\alec\Projects\CD_universal_control\Simulations\ECD_control\ECD_pulse_construction\ECD_pulse_construction.py in conditional_displacement(beta, alpha, storage, qubit, buffer_time, curvature_correction, chi_prime_correction, kerr_correction, pad, finite_difference, output)
#     522
#     523     # ratios of the displacements
# --> 524     r, r0, r1, r2 = ratios(alpha, tw)
#     525
#     526     cavity_dac_pulse, qubit_dac_pulse = construct_CD(alpha, tw, r, r0, r1, r2)
#
# D:\alec\Projects\CD_universal_control\Simulations\ECD_control\ECD_pulse_construction\ECD_pulse_construction.py in ratios(alpha, tw)
#     506             )
#     507
# --> 508         result = fmin(cost, x0=[r, r0, r1, r2], xtol=1e-8, ftol=1e-8)
#     509         r = result[0]
#     510         r0 = result[1]
#
# C:\ProgramData\Miniconda3\envs\opt3\lib\site-packages\scipy\optimize\optimize.py in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     575             'initial_simplex': initial_simplex}
#     576
# --> 577     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     578     if full_output:
#     579         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# C:\ProgramData\Miniconda3\envs\opt3\lib\site-packages\scipy\optimize\optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     737         xbar = np.add.reduce(sim[:-1], 0) / N
#     738         xr = (1 + rho) * xbar - rho * sim[-1]
# --> 739         fxr = func(xr)
#     740         doshrink = 0
#     741
#
# C:\ProgramData\Miniconda3\envs\opt3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     459     def function_wrapper(*wrapper_args):
#     460         ncalls[0] += 1
# --> 461         return function(*(wrapper_args + args))
#     462
#     463     return ncalls, function_wrapper
#
# D:\alec\Projects\CD_universal_control\Simulations\ECD_control\ECD_pulse_construction\ECD_pulse_construction.py in cost(x)
#     475             epsilon = cavity_dac_pulse * epsilon_m
#     476             flip_idx = int(len(epsilon) / 2)
# --> 477             alpha_g, alpha_e = get_ge_trajectories(
#     478                 epsilon,
#     479                 delta=delta,
#
# D:\alec\Projects\CD_universal_control\Simulations\ECD_control\ECD_pulse_construction\ECD_pulse_construction.py in get_ge_trajectories(epsilon, delta, chi, chi_prime, Ks, kappa, flip_idxs, finite_difference)
#     293     alpha_e_init = 0 + 0j
#     294     for epsilon in epsilons:
# --> 295         alpha_g_current, alpha_e_current = f(epsilon, alpha_g_init, alpha_e_init)
#     296         if g_state == 0:
#     297             alpha_g.append(alpha_g_current)
#
# D:\alec\Projects\CD_universal_control\Simulations\ECD_control\ECD_pulse_construction\ECD_pulse_construction.py in <lambda>(epsilon, alpha_g_init, alpha_e_init)
#     276         else alpha_from_epsilon_ge
#     277     )
# --> 278     f = lambda epsilon, alpha_g_init, alpha_e_init: func(
#     279         epsilon,
#     280         delta=delta,
#
# D:\alec\Projects\CD_universal_control\Simulations\ECD_control\ECD_pulse_construction\ECD_pulse_construction.py in alpha_from_epsilon_ge_finite_difference(epsilon_array, delta, chi, chi_prime, Ks, kappa, alpha_g_init, alpha_e_init)
#     242                 - 2j * Ks * np.abs(alpha_g[j]) ** 2 * alpha_g[j]
#     243                 - (kappa / 2.0) * alpha_g[j]
# --> 244                 - 1j * epsilon_array[j]
#     245             )
#     246             + alpha_g[j - 1]
#
# KeyboardInterrupt:

# %%
#plotting the pulse
#clip = qubit.pulse.sigma*qubit.pulse.chop
#cavity_dac_pulse = cavity_dac_pulse[clip:-clip]
#qubit_dac_pulse = qubit_dac_pulse[clip:-clip]
plt.plot(np.real(cavity_dac_pulse), label='re(epsilon_dac)')
plt.plot(np.imag(cavity_dac_pulse), label='imag(epsilon_dac)')
plt.plot(np.real(qubit_dac_pulse), label='re(qubit_dac)')
plt.plot(np.imag(qubit_dac_pulse), label='imag(qubit_dac)')
plt.legend()

# %%
chi = 2*np.pi*1e-6*storage_params['chi_kHz']
chi_prime = 2*np.pi*1e-9*storage_params['chi_prime_Hz']
Ks = 2*np.pi*1e-9*storage_params['Ks_Hz']
delta = -chi/2.0 
plt.figure()

epsilon = epsilon_m*cavity_dac_pulse
flip_idx = int(len(epsilon)/2)
delta = -chi/2.0
alpha_g, alpha_e = get_ge_trajectories(epsilon, delta=delta, chi=chi, flip_idxs=[flip_idx], finite_difference=True)
plot_trajs_complex(alpha_g, alpha_e)
mid_disp = np.abs(alpha_g[flip_idx] + alpha_e[flip_idx])
final_disp = np.abs(alpha_g[-1] + alpha_e[-1])
first_radius = np.abs(
    (alpha_g[int(flip_idx / 2)] + alpha_e[int(flip_idx / 2)]) / 2.0
)
second_radius = np.abs(
    (alpha_g[int(3 * flip_idx / 2)] + alpha_e[int(3 * flip_idx / 2)]) / 2.0
)
print('mid_disp: %.4f' % mid_disp )
print('final_disp: %.4f' % final_disp )
print('first_radius: %.4f' % first_radius )
print('second_radius: %.4f' % second_radius )
# Out:
# mid_disp: 80.0928
# final_disp: 0.0606
# first_radius: 40.1396
# second_radius: 0.1182

# %%
N = 30
N2 = 2
rho0 = qt.tensor(qt.basis(N2,0),qt.basis(N,0))
#rho0 = qt.tensor(qt.thermal_dm(N2, 0.05), qt.thermal_dm(N, 0.05))


#qubit_detune = 2*np.pi*1e-9*1e6
qubit_detune = 0
cavity_drive_scale = 1.0
qubit_drive_scale = 1.0
#vlad's anharmonicity
Kq = -2 * np.pi * 1e-3 * 2 * 200
kappa = 0
gamma_down_qubit = 0
#I know this is not quite correct but let's try it
#T2E = 20.0e3
gamma_2 = 0
gamma_phi_qubit = gamma_2 - gamma_down_qubit/2.0
#
#doing master equation simulation
epsilon = cavity_drive_scale*2*np.pi*1e-3*storage_params['epsilon_m_MHz']*cavity_dac_pulse
Omega = qubit_drive_scale*Omega_m*qubit_dac_pulse
me_options = {'Kq':Kq, 'delta':delta, 'chi':chi,
    'chi_prime':chi_prime, 'Ks':Ks, 'kappa':kappa, 'gamma_down_qubit':gamma_down_qubit,
    'gamma_phi_qubit':gamma_phi_qubit, 'output':True, 'qubit_detune':qubit_detune}
result, alpha = simulate_master_equation_superoperator(epsilon = 1j*epsilon,rho0=rho0,Omega=1j*Omega, **me_options)
# Out:
# Solving for alpha(t)
# Constructing Hamiltonian
# Running mesolve:
# 10.0%. Run time:   0.35s. Est. time left: 00:00:00:03
# 20.0%. Run time:   0.92s. Est. time left: 00:00:00:03
# 30.1%. Run time:   1.22s. Est. time left: 00:00:00:02
# 40.0%. Run time:   1.59s. Est. time left: 00:00:00:02
# 50.0%. Run time:   1.88s. Est. time left: 00:00:00:01
# 60.0%. Run time:   2.18s. Est. time left: 00:00:00:01
# 70.0%. Run time:   2.44s. Est. time left: 00:00:00:01
# 80.1%. Run time:   2.74s. Est. time left: 00:00:00:00
# 90.0%. Run time:   3.05s. Est. time left: 00:00:00:00
# Total run time:   3.31s

# %%
plot_expect_displace(result.states, alpha)

# %%
#rhof = qt.ket2dm(result.states[-1])
rhof = result.states[-1]
g = qt.tensor(qt.basis(N2,0), qt.identity(N))
e = qt.tensor(qt.basis(N2,1), qt.identity(N))
rhof_g = (g.dag()*rhof*g).unit()
rhof_e = (e.dag()*rhof*e).unit()
#correct final frame
D =  qt.displace(N,alpha[-1])
rhof_g =D*rhof_g*D.dag()
rhof_e =D*rhof_e*D.dag()

# %%
plot_wigner(rhof_g, xvec)
plot_wigner(-1*rhof_e, xvec)

# %%
fid_g = qt.fidelity(rhof_g, psi_e)**2
fid_e = qt.fidelity(rhof_e, psi_g)**2
print('fid g: %.6f fid e: %.6f' % (fid_g, fid_e))
# Out:
# fid g: 0.992050 fid e: 0.328499

# %%
alpha_g, alpha_e = get_ge_trajectories(epsilon, delta=delta, chi=chi, flip_idxs=[int(len(epsilon)/2)])
plot_trajs_complex(alpha_g, alpha_e)
# Out:
# C:\ProgramData\Miniconda3\envs\opt3\lib\site-packages\scipy\integrate\_ivp\common.py:46: UserWarning: `rtol` is too low, setting to 2.220446049250313e-14
#   warn("`rtol` is too low, setting to {}".format(100 * EPS))
