# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from ECD_control.ECD_pulse_construction.ECD_pulse_construction import *
from ECD_control.ECD_tools.ECD_tools import *
import qutip as qt

# %%
#the parameters in our circuit. Can be user defined, or loaded from the result of an ECD optimization.
fname = 'fock_1.npz'
betas = np.load(fname)['betas']
phis = np.load(fname)['phis']
thetas = np.load(fname)['thetas']

#betas = np.array([2*np.sqrt(2.0), -2*np.sqrt(2.0),0.0])
#phis = np.array([0.0, 0.0,0.0])
#thetas = np.array([0.0,0.0])
#thetas = np.array([np.pi/2.0,0.0,np.pi/2.0])
#betas = np.array([2*np.sqrt(2.0),0])
#phis = np.array([0.0,0])
#thetas = np.array([np.pi/2.0,np.pi/2.0])
print('betas:' + str(betas))
print('phis:' + str(phis))
print('thetas:' + str(thetas))
# Out:
# betas:[-4.7169000e-01+1.1799515e+00j -5.4833227e-01-5.9778297e-01j
#   6.1424845e-01-4.2482018e-01j -4.2800032e-02-4.6761116e-01j
#   3.2033236e-05-9.4282441e-06j]
# phis:[ 0.        -1.5709312 -1.5706469  1.570543  -3.141307 ]
# thetas:[-1.5707908 -1.2903942  0.9143192 -1.7336673  1.5707104]

# %%
#Now, the unitary simulation
print('the circuit:')
print('betas: ' + str(betas))
print('phis deg: ' + str(180*phis/np.pi))
print('thetas deg: ' + str(180*thetas/np.pi))
N = 30
fock = 1
psi0 = qt.tensor(qt.basis(2,0),qt.basis(N,0))
psit = qt.tensor(qt.basis(2,1),qt.basis(N,fock))
psis = unitary_circuit_sim(psi0, betas, phis, thetas, N)
psif = psis[-1]
plot_expect(psis)
g = qt.tensor(qt.basis(2,0), qt.identity(N))
e = qt.tensor(qt.basis(2,1), qt.identity(N))
psi_g = (g.dag()*psif).unit()
psi_e = (e.dag()*psif).unit()
xvec = np.linspace(-3,3,81)
plot_wigner(psi_g, xvec)
plot_wigner(psi_e, xvec, invert=False)
fid = qt.fidelity(psif, psit)**2
print('unitary fid: %.5f' % fid)
plt.title('unitary sim')
# Out:
# the circuit:
# betas: [-4.7169000e-01+1.1799515e+00j -5.4833227e-01-5.9778297e-01j
#   6.1424845e-01-4.2482018e-01j -4.2800032e-02-4.6761116e-01j
#   3.2033236e-05-9.4282441e-06j]
# phis deg: [   0.       -90.00772  -89.99143   89.98549 -179.98364]
# thetas deg: [-89.99968  -73.934135  52.386627 -99.33182   89.99507 ]
# unitary fid: 0.99822
# Text(0.5, 1.0, 'unitary sim')

# %%
#Our cavity and qubit. When using pulse construction on the FPGA, these objects can be loaded, and 
#the pre-calibrated values can be used. Here, we are making a "FakeCavity" and a "FakeQubit" in order
#to demonstrate the pulse construction when not connected to the FPGA_lib.

#The following parameters are assumed to be defined under your cavity and qubit entity object in FPGA lib.
#storage_params = {'chi_kHz': -17.78, 'chi_prime_Hz': 0, 'Ks_Hz': 0, 'epsilon_m_MHz': 0, 'unit_amp': 0.01, 'sigma': 11, 'chop': 4}
storage_params = {
        "chi_kHz":  -17.78,
        "chi_prime_Hz": 0,
        "Ks_Hz": 0,
        "epsilon_m_MHz": 436.522553,
        "unit_amp": 0.015845,
        "sigma": 11,
        "chop": 4,
    }
qubit_params = {'unit_amp': 0.1, 'sigma': 6, 'chop': 4, 'detune':0}

#calculating epsilon m
'''
wave = storage_params['unit_amp']*gaussian_wave(storage_params['sigma'], storage_params['chop'])
epsilon_m = 1/np.trapz(wave)
epsilon_m_MHz = 1e3*epsilon_m/2/np.pi
print('epsilon_m_MHz: %.6f' % epsilon_m_MHz)
storage_params['epsilon_m_MHz'] = epsilon_m_MHz
'''

pi = rotate(np.pi, phi=0, sigma=qubit_params['sigma'], chop=qubit_params['chop'], dt=1)
Omega_m = np.real(np.max(pi))/qubit_params['unit_amp']

#creating the "Fake storage" and "Fake qubit"
storage = FakeStorage(**storage_params)
qubit = FakeQubit(**qubit_params)

#The alpha used during the ECD gates.
alpha_CD = 30.0
#Buffer time between R and ECD pulses.
buffer_time = 0

# %%
#generating the conditional displacement circuit with all corrections.
cd_circuit_dict = conditional_displacement_circuit(betas, phis, thetas, storage, qubit,
                     alpha_CD,  buffer_time=buffer_time, kerr_correction = False, chi_prime_correction=False, final_disp=True, pad=True, output=True,
                     echo_qubit_pulses=False, qubit_phase_correction=True)
cavity_dac_pulse, qubit_dac_pulse, = cd_circuit_dict['cavity_dac_pulse'], cd_circuit_dict['qubit_dac_pulse']
print(cd_circuit_dict['alphas'])
# Out:
# 0
#   mid_disp: 0.0002 final_disp: 0.0006 first_radius: 29.9999 second_radius: 30.0002tw: 189alpha: 30.0beta: 1.5615842952767771diff: 0.2908454551736277
#   mid_disp: 0.0006 final_disp: 0.0005 first_radius: 30.0010 second_radius: 30.0002tw: 153alpha: 30.0beta: 1.320309200941717diff: 0.049570360838567584
#   mid_disp: 0.0010 final_disp: 0.0017 first_radius: 30.0004 second_radius: 30.0004tw: 147alpha: 30.0beta: 1.280084139310409diff: 0.009345299207259572
#   mid_disp: 0.0010 final_disp: 0.0018 first_radius: 30.0004 second_radius: 30.0004tw: 145alpha: 30.0beta: 1.2666799367083414diff: -0.004058903394807967
#   mid_disp: 0.0010 final_disp: 0.0018 first_radius: 30.0966 second_radius: 30.0966tw: 145alpha: 30.096130915407617beta: 1.2707388401031676diff: 1.8207657603852567e-14
#   mid_disp: 0.0010 final_disp: 0.0018 first_radius: 30.0966 second_radius: 30.09661
#   mid_disp: 0.6905 final_disp: 0.0274 first_radius: 30.3782 second_radius: 30.7478
# C:\ProgramData\Miniconda3\envs\opt3\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
#   mid_disp: 0.0001 final_disp: 0.0004 first_radius: 29.9994 second_radius: 29.9996tw: 121alpha: 30.0beta: 1.1057738583161798diff: 0.29459398198866515
#   mid_disp: 0.0005 final_disp: 0.0004 first_radius: 29.9998 second_radius: 29.9997tw: 88alpha: 30.0beta: 0.8847737284897147diff: 0.07359385216220005
#   mid_disp: 0.0003 final_disp: 0.0009 first_radius: 29.9999 second_radius: 29.9999tw: 80alpha: 30.0beta: 0.831155925371326diff: 0.01997604904381134
#   mid_disp: 0.0001 final_disp: 0.0011 first_radius: 30.0000 second_radius: 30.0002tw: 78alpha: 30.0beta: 0.8177558998282721diff: 0.0065760235007574774
#   mid_disp: 0.0001 final_disp: 0.0011 first_radius: 30.0000 second_radius: 30.0002tw: 77alpha: 30.0beta: 0.8108710176151334diff: -0.00030885871238128804
#   mid_disp: 0.0001 final_disp: 0.0011 first_radius: 30.0000 second_radius: 30.00022
#   mid_disp: 0.0010 final_disp: 0.0001 first_radius: 29.9996 second_radius: 30.0001tw: 111alpha: 30.0beta: 1.0387581191076454diff: 0.291915853978556
#   mid_disp: 0.0001 final_disp: 0.0011 first_radius: 30.0000 second_radius: 30.0002tw: 79alpha: 30.0beta: 0.8242761728911346diff: 0.07743390776204528
#   mid_disp: 0.0006 final_disp: 0.0003 first_radius: 29.9999 second_radius: 29.9999tw: 71alpha: 30.0beta: 0.7706484606043413diff: 0.02380619547525198
#   mid_disp: 0.0007 final_disp: 0.0003 first_radius: 29.9999 second_radius: 30.0000tw: 68alpha: 30.0beta: 0.7507230373330647diff: 0.0038807722039753134
#   mid_disp: 0.0007 final_disp: 0.0003 first_radius: 29.9999 second_radius: 30.0000tw: 67alpha: 30.0beta: 0.7438380614948785diff: -0.0030042036342108336
#   mid_disp: 0.0007 final_disp: 0.0004 first_radius: 30.1211 second_radius: 30.1212tw: 67alpha: 30.12116361570044beta: 0.7468422651290899diff: 5.551115123125783e-16
#   mid_disp: 0.0007 final_disp: 0.0004 first_radius: 30.1211 second_radius: 30.12123
#   mid_disp: 0.0006 final_disp: 0.0003 first_radius: 29.9999 second_radius: 30.0000tw: 70alpha: 30.0beta: 0.7641282290113882diff: 0.29456242023834744
#   mid_disp: 0.0011 final_disp: 0.0013 first_radius: 30.0006 second_radius: 29.9999tw: 43alpha: 30.0beta: 0.5829760940061003diff: 0.11341028523305952
#   mid_disp: 0.0009 final_disp: 0.0001 first_radius: 29.9998 second_radius: 30.0016tw: 34alpha: 30.0beta: 0.5228383207091373diff: 0.0532725119360965
#   mid_disp: 0.0002 final_disp: 0.0005 first_radius: 30.0000 second_radius: 29.9978tw: 30alpha: 30.0beta: 0.49599602195084075diff: 0.026430213177799977
#   mid_disp: 0.0008 final_disp: 0.0008 first_radius: 30.0001 second_radius: 30.0000tw: 28alpha: 30.0beta: 0.4826082476907798diff: 0.013042438917739041
#   mid_disp: 0.0008 final_disp: 0.0008 first_radius: 30.0001 second_radius: 30.0000tw: 27alpha: 30.0beta: 0.47572305589828723diff: 0.006157247125246457
#   mid_disp: 0.0007 final_disp: 0.0008 first_radius: 30.0001 second_radius: 30.0000tw: 26alpha: 30.0beta: 0.4692026421700954diff: -0.00036316660294538616
#   mid_disp: 0.0007 final_disp: 0.0008 first_radius: 30.0001 second_radius: 30.00004
# [30.096130915407617, 30.0, 30.12116361570044, 30.0]

# %%
#plotting the pulse
#clip = qubit.pulse.sigma*qubit.pulse.chop
#cavity_dac_pulse = cavity_dac_pulse[clip:-clip]
#qubit_dac_pulse = qubit_dac_pulse[clip:-clip]
plt.plot(np.real(cavity_dac_pulse), label='re(epsilon_dac)')
plt.plot(np.imag(cavity_dac_pulse), label='imag(epsilon_dac)')
plt.plot(np.real(qubit_dac_pulse), label='re(qubit_dac)')
plt.plot(np.imag(qubit_dac_pulse), label='imag(qubit_dac)')
plt.legend()

# %%
chi = 2*np.pi*1e-6*storage_params['chi_kHz']
chi_prime = 2*np.pi*1e-9*storage_params['chi_prime_Hz']
Ks = 2*np.pi*1e-9*storage_params['Ks_Hz']
delta = -chi/2.0 
plt.figure()

epsilon = epsilon_m*cavity_dac_pulse
flip_idx = int(len(epsilon)/2)
delta = -chi/2.0
alpha_g, alpha_e = get_ge_trajectories(epsilon, delta=delta, chi=chi, flip_idxs=[flip_idx], finite_difference=True)
plot_trajs_complex(alpha_g, alpha_e)
mid_disp = np.abs(alpha_g[flip_idx] + alpha_e[flip_idx])
final_disp = np.abs(alpha_g[-1] + alpha_e[-1])
first_radius = np.abs(
    (alpha_g[int(flip_idx / 2)] + alpha_e[int(flip_idx / 2)]) / 2.0
)
second_radius = np.abs(
    (alpha_g[int(3 * flip_idx / 2)] + alpha_e[int(3 * flip_idx / 2)]) / 2.0
)
print('mid_disp: %.4f' % mid_disp )
print('final_disp: %.4f' % final_disp )
print('first_radius: %.4f' % first_radius )
print('second_radius: %.4f' % second_radius )
# Out:
# mid_disp: 95.0611
# final_disp: 0.0427
# first_radius: 47.6938
# second_radius: 47.7165

# %%
N = 30
N2 = 2
rho0 = qt.tensor(qt.basis(N2,0),qt.basis(N,0))
#rho0 = qt.tensor(qt.thermal_dm(N2, 0.05), qt.thermal_dm(N, 0.05))


#qubit_detune = 2*np.pi*1e-9*1e6
qubit_detune = 0
cavity_drive_scale = 1.0
qubit_drive_scale = 1.0
#vlad's anharmonicity
Kq = -2 * np.pi * 1e-3 * 2 * 200
kappa = 0
gamma_down_qubit = 0
#I know this is not quite correct but let's try it
#T2E = 20.0e3
gamma_2 = 0
gamma_phi_qubit = gamma_2 - gamma_down_qubit/2.0
#
#doing master equation simulation
epsilon = cavity_drive_scale*2*np.pi*1e-3*storage_params['epsilon_m_MHz']*cavity_dac_pulse
Omega = qubit_drive_scale*Omega_m*qubit_dac_pulse
me_options = {'Kq':Kq, 'delta':delta, 'chi':chi,
    'chi_prime':chi_prime, 'Ks':Ks, 'kappa':kappa, 'gamma_down_qubit':gamma_down_qubit,
    'gamma_phi_qubit':gamma_phi_qubit, 'output':True, 'qubit_detune':qubit_detune}
result, alpha = simulate_master_equation(epsilon = 1j*epsilon,rho0=rho0,Omega=1j*Omega, **me_options)
# Out:
# Solving for alpha(t)
# Constructing Hamiltonian
# Running mesolve:
# 10.0%. Run time:   0.44s. Est. time left: 00:00:00:03
# 20.1%. Run time:   0.66s. Est. time left: 00:00:00:02
# 30.0%. Run time:   0.80s. Est. time left: 00:00:00:01
# 40.0%. Run time:   0.92s. Est. time left: 00:00:00:01
# 50.0%. Run time:   1.05s. Est. time left: 00:00:00:01
# 60.0%. Run time:   1.17s. Est. time left: 00:00:00:00
# 70.1%. Run time:   1.30s. Est. time left: 00:00:00:00
# 80.0%. Run time:   1.44s. Est. time left: 00:00:00:00
# 90.0%. Run time:   1.57s. Est. time left: 00:00:00:00
# Total run time:   1.71s

# %%
rhof = qt.ket2dm(result.states[-1])
#rhof = result.states[-1]
g = qt.tensor(qt.basis(N2,0), qt.identity(N))
e = qt.tensor(qt.basis(N2,1), qt.identity(N))
rhof_g = (g.dag()*rhof*g).unit()
rhof_e = (e.dag()*rhof*e).unit()
#correct final frame
D =  qt.displace(N,alpha[-1])
rhof_g =D*rhof_g*D.dag()
rhof_e =D*rhof_e*D.dag()

# %%
plot_wigner(rhof_g, xvec)
plot_wigner(-1*rhof_e, xvec)

# %%
fid_g = qt.fidelity(rhof_g, psi_e)**2
fid_e = qt.fidelity(rhof_e, psi_g)**2
print('fid g: %.6f fid e: %.6f' % (fid_g, fid_e))
# Out:
# fid g: 0.999935 fid e: 0.963565

# %%
alpha_g, alpha_e = get_ge_trajectories(epsilon, delta=delta, chi=chi, flip_idxs=[int(len(epsilon)/2)])
plot_trajs_complex(alpha_g, alpha_e)
# Out:
# C:\ProgramData\Miniconda3\envs\opt3\lib\site-packages\scipy\integrate\_ivp\common.py:46: UserWarning: `rtol` is too low, setting to 2.220446049250313e-14
#   warn("`rtol` is too low, setting to {}".format(100 * EPS))
